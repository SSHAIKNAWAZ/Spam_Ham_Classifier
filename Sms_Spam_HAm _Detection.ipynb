# %% [markdown]
# <center><font color= 'Black' style = 'font-family:verdana ; font-size:25px'>SMS Spam Detection Project</font></center>
# <hr style="color: black; height: 1px;">
# <b><font color= '#067F7D' style = 'font-family:cambria ; font-size:20px'>Overview</font></b><br>
#
# <font color="black" style="font-family:Cambria ;font-size:16px">This project implements a machine learning model for detecting spam SMS messages. The model distinguishes between legitimate ("ham") and spam messages based on a dataset of labeled SMS texts.</font><br>
#
# <b><font color= '#067F7D' style = 'font-family:cambria ; font-size:20px'>Dataset :</font></b><br>
#
# <b><font color=black style='font-family:Cambria; font-size:17px'>The SMS Spam Collection dataset consists of 5,574 SMS messages in English, sourced from various public and research-oriented sources :</font></b><br>
#
# - <font color="brown" style="font-family:Cambria; font-size:15px">`Grumbletext Web site: 425 SMS spam messages.`</font><br>
# - <font color="brown" style="font-family:Cambria; font-size:15px">`NUS SMS Corpus (NSC): 3,375 randomly chosen ham messages.`</font><br>
# - <font color="brown" style="font-family:Cambria; font-size:15px">`Caroline Tag's PhD Thesis: 450 SMS ham messages.`</font><br>
# - <font color="brown" style="font-family:Cambria; font-size:15px">`SMS Spam Corpus v.0.1 Big: 1,002 ham messages and 322 spam messages.`</font><br>
#
# <b><font color= '#067F7D' style = 'font-family:cambria ; font-size:20px'>Project Structure :</font></b><br>
#
# <b><font color=black style='font-family:Cambria; font-size:17px'>The project is structured as follows:</font></b><br>
#
# - <font color="brown" style="font-family:Cambria; font-size:15px">`train_model.ipynb`: Jupyter notebook for data preprocessing, model training, and saving the model.</font><br>
# - <font color="brown" style="font-family:Cambria; font-size:15px">`vectorizer.pkl`: Pickle file containing the TF-IDF vectorizer used to preprocess text data.</font><br>
# - <font color="brown" style="font-family:Cambria; font-size:15px">`model.pkl:` Pickle file containing the trained machine learning model for SMS spam detection.</font><br>
# - <font color="brown" style="font-family:Cambria; font-size:15px">`streamlit_app.py`: Streamlit application for deploying the trained model.</font><br>
# - <font color="brown" style="font-family:Cambria; font-size:15px">`requirements.txt`: List of Python packages required to run the project..</font><br>
# <hr>
#
#
# <b><font color= '#067F7D' style = 'font-family:cambria ; font-size:20px'>Expected Outcome :</font></b>
# <br>
#
# <font color="black" style="font-family:Cambria ;font-size:16px">The primary outcome of this project is a web-based application that can classify SMS messages as spam or ham with high accuracy. Users can input their SMS messages into the app and receive instant predictions.</font><br>
# <hr>
#
# <b><font color= '#067F7D' style = 'font-family:cambria ; font-size:20px'>Model Architecture:</font></b><br>
#
# <font color="black" style="font-family:Cambria ;font-size:16px">Several machine learning models were trained and fine-tuned for this project, including: <font><br>
#   - <font color="black" style="font-family:Cambria ;font-size:16px"> Multinomial Naive Bayes<font><br>
#   - <font color="black" style="font-family:Cambria ;font-size:16px"> Support Vector Machines<font><br>
#   - <font color="black" style="font-family:Cambria ;font-size:16px"> Extra Trees Classifier <font><br>
#   - <font color="black" style="font-family:Cambria ;font-size:16px">Random Forest Classifier <font><br>
#   - <font color="black" style="font-family:Cambria ;font-size:16px">AdaBoost Classifier <font><br>
#   - <font color="black" style="font-family:Cambria ;font-size:16px">XGBoost Classifier <font><br>
#   - <font color="black" style="font-family:Cambria ;font-size:16px">KNN Classifier <font><br>
#   - <font color="black" style="font-family:Cambria ;font-size:16px"> Logistic Regression<font><br>
#
# <hr>
#
#
# <font color="black" style="font-family:Cambria ;font-size:16px">The models were trained using a dataset of 5,574 SMS messages, with a variety of text preprocessing steps applied, including: <font><br>
#   - <font color="black" style="font-family:Cambria ;font-size:16px"> Tokenization<font><br>
#   - <font color="black" style="font-family:Cambria ;font-size:16px">Stop word removal<font><br>
#   - <font color="black" style="font-family:Cambria ;font-size:16px"> Stemming <font><br>
#   - <font color="black" style="font-family:Cambria ;font-size:16px"> Count Vectorizer <font><br>
#   - <font color="black" style="font-family:Cambria ;font-size:16px"> TF-IDF vectorization <font><br>
#
# <hr>
#
# <b><font color= '#067F7D' style = 'font-family:cambria ; font-size:20px'>Model Evaluation:</font></b><br>
#
#   - <font color="black" style="font-family:Cambria ;font-size:16px">The models were evaluated using precision, and accuracy metrics. Hyperparameter tuning was performed using GridSearchCV to optimize model performance.<font><br>
#
# <hr>
# <b><font color= '#067F7D' style = 'font-family:cambria ; font-size:20px'>Performance:</font></b><br>
#
#   - <font color="black" style="font-family:Cambria ;font-size:16px">The final deployed model achieved the following performance metrics:<font><br>
#   - <font color="black" style="font-family:Cambria ;font-size:16px">`Accuracy 97.0` where as `Precision is 1`<font>
#     <br>
# <hr>
#
# <b><font color= '#067F7D' style = 'font-family:cambria ; font-size:20px'>Deployment:</font></b><br>
#
#   - <font color="black" style="font-family:Cambria ;font-size:16px">The optimized model was deployed as a web application using Streamlit, allowing for real-time SMS classification. The application includes all necessary data preprocessing steps and provides an intuitive user interface for seamless user interaction.<font><br>

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('spam.csv',encoding='latin1')

# %%
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 5275  ham                      Oh yeah clearly it's my fault        NaN
# 4833  ham                      I hope your pee burns tonite.        NaN
# 2226  ham            If you have belive me. Come to my home.        NaN
# 4511  ham        Now project pa. After that only i can come.        NaN
# 1725  ham  You know there is. I shall speak to you in  &l...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 5275        NaN        NaN
# 4833        NaN        NaN
# 2226        NaN        NaN
# 4511        NaN        NaN
# 1725        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
# 1. Data cleaning
# 2. EDA
# 3. Text Preprocessing
# 4. Model building
# 5. Evaluation
# 6. Improvement
# 7. Website
# 8. Deploy

# %% [markdown]
# ## 1. Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
# drop last 3 cols
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 4429  ham        Yar lor... How u noe? U used dat route too?
# 485   ham      If we win its really no 1 side for long time.
# 4719  ham  Forgot to tell Ì_ smth.. Can Ì_ like number th...
# 1265  ham  Im in inperialmusic listening2the weirdest tra...
# 1042  ham          Easy ah?sen got selected means its good..

# %%
# renaming the cols
df.rename(columns={'v1':'target','v2':'text'},inplace=True)
df.sample(5)
# Out:
#      target                                               text
# 5262    ham                            Did you see that film:)
# 559     ham  Aiyo... U always c our ex one... I dunno abt m...
# 1483    ham  Purity of friendship between two is not about ...
# 1623    ham       Ah, well that confuses things, doesnÛ÷t it?
# 2033    ham                            IM GONNA MISS U SO MUCH

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
# missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
# check for duplicate values
df.duplicated().sum()
# Out:
# 403

# %%
# remove duplicates
df = df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# ## 2.EDA

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(), labels=['ham','spam'],autopct="%0.2f")
plt.show()

# %%
# Data is imbalanced

# %%
import nltk

# %%
# !pip install nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shaik\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['num_characters'] = df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
# num of words
df['num_words'] = df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
df['num_sentences'] = df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    18.455794       1.965564
# std         58.236293    13.324758       1.448541
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
# ham
df[df['target'] == 0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123782       1.820195
# std         56.358207    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
#spam
df[df['target'] == 1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.970904
# std         30.137753    7.008418       1.488425
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,10))
plt.subplot(3,1,1)
sns.histplot(df[df['target']==0]['num_characters'],label='ham')
sns.histplot(df[df['target']==1]['num_characters'],color='red',label='spam')
plt.legend()

plt.subplot(3,1,2)
sns.histplot(df[df['target']==0]['num_words'],label='ham')
sns.histplot(df[df['target']==1]['num_words'],color='red',label='spam')
plt.legend()

plt.subplot(3,1,3)
sns.histplot(df[df['target']==0]['num_sentences'],label='ham')
sns.histplot(df[df['target']==1]['num_sentences'],color='red',label='spam')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(12,10))
plt.subplot(3,1,1)
sns.distplot(df[df['target']==0]['num_characters'],label='ham')
sns.distplot(df[df['target']==1]['num_characters'],color='red',label='spam')
plt.legend()

plt.subplot(3,1,2)
sns.distplot(df[df['target']==0]['num_words'],label='ham')
sns.distplot(df[df['target']==1]['num_words'],color='red',label='spam')
plt.legend()

plt.subplot(3,1,3)
sns.distplot(df[df['target']==0]['num_sentences'],label='ham')
sns.distplot(df[df['target']==1]['num_sentences'],color='red',label='spam')
plt.legend()

plt.show()
# Out:
# C:\Users\shaik\AppData\Local\Temp\ipykernel_4544\2725417602.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['target']==0]['num_characters'],label='ham')
# C:\Users\shaik\AppData\Local\Temp\ipykernel_4544\2725417602.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.pairplot(df,hue='target')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.heatmap(df[['target','num_characters','num_words','num_sentences']].corr(),annot=True)
# Out:
# <Axes: >

# %%
corr=df[['target','num_characters','num_words','num_sentences']].corr()

# %%
new=corr['target'].drop('target')

# %%
for i in new.index:
    print (f'{i} Vs Target Variable : ',new[i])
# Out:
# num_characters Vs Target Variable :  0.38471706671430833
# num_words Vs Target Variable :  0.26291248543035906
# num_sentences Vs Target Variable :  0.2639389676149628

# %%
plt.figure(figsize=(4, 3))
sns.heatmap(new.to_frame(), annot=True, cmap='coolwarm',vmin=-1,vmax=1)
plt.title('Correlation with Target ')
plt.show()

# %%
# sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# ## 3. Data Preprocessing
# - Lower case
# - Tokenization
# - Removing special characters
# - Removing stop words and punctuation
# - Stemming

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import string
ps=PorterStemmer()

# %%
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)
    
    y = []
    for i in text:
        if i.isalnum():
            y.append(i)
    
    text = y[:]
    y.clear()
    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
            
    text = y[:]
    y.clear()
    
    for i in text:
        y.append(ps.stem(i))
    
            
    return " ".join(y)

# %%
transform_text("I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.")
# Out:
# 'gon na home soon want talk stuff anymor tonight k cri enough today'

# %%
df['text'][10]
# Out:
# "I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today."

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('loving')
# Out:
# 'love'

# %%
df['transformed_text'] = df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
spam_wc = wc.generate(df[df['target'] == 1]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(spam_wc)
plt.show()

# %%
ham_wc = wc.generate(df[df['target'] == 0]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(ham_wc)
plt.show()

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
spam_corpus=[]
for i in df[df['target']==1]['transformed_text'].tolist():
    for j in i.split():
        spam_corpus.append(j)

# %%
ham_corpus=[]
for i in df[df['target']==0]['transformed_text'].tolist():
    for j in i.split():
        ham_corpus.append(j)

# %%
from collections import Counter
dic=Counter(spam_corpus)
dic1=Counter(ham_corpus)

# %%
# extracting the keys and values from the dictionary
words=list(dic.keys())
counts=list(dic.values())

# %%
words[:10]
# Out:
# ['free', 'entri', '2', 'wkli', 'comp', 'win', 'fa', 'cup', 'final', 'tkt']

# %%
counts[:10]
# Out:
# [191, 21, 155, 9, 8, 48, 2, 3, 14, 2]

# %%
most_common_30 = dic.most_common(30)
common_df = pd.DataFrame(most_common_30)

# %%
common_df.head(3)
# Out:
#       0    1
# 0  call  320
# 1  free  191
# 2     2  155

# %%
most_common_30_ham = dic1.most_common(30)
common_df1 = pd.DataFrame(most_common_30_ham)

# %%
# Create the bar plot
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.barplot(x=common_df[0], y=common_df[1],label='spam')
plt.xticks(rotation=90)
plt.legend()
plt.subplot(1,2,2)
sns.barplot(x=common_df1[0], y=common_df1[1],label='Ham')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# ## 4. Model Building

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000)

# %%
X = tfidf.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y = df['target'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8694390715667312
# [[788 108]
#  [ 27 111]]
# 0.5068493150684932

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %%
# first we have used the count vectorizer and performed all three then we have used 
# tfidf vectorizer MNB performed well so we are using the TF-idf-->mnb (Multinomial Navie bayes)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc, 
    'NB': mnb, 
    'DT': dtc, 
    'LR': lrc, 
    'RF': rfc, 
    'AdaBoost': abc, 
    'BgC': bc, 
    'ETC': etc,
    'GBDT':gbdt,
    'xgb':xgb
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    
    return accuracy,precision

# %%
train_classifier(svc,X_train,y_train,X_test,y_test)
# Out:
# (0.9758220502901354, 0.9747899159663865)

# %%
accuracy_scores = []
precision_scores = []

for name,clf in clfs.items():
    
    current_accuracy,current_precision = train_classifier(clf, X_train,y_train,X_test,y_test)
    
    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  SVC
# Accuracy -  0.9758220502901354
# Precision -  0.9747899159663865
# For  KN
# Accuracy -  0.9052224371373307
# Precision -  1.0
# For  NB
# Accuracy -  0.9709864603481625
# Precision -  1.0
# For  DT
# Accuracy -  0.9323017408123792
# Precision -  0.8333333333333334
# For  LR
# Accuracy -  0.9584139264990329
# Precision -  0.9702970297029703
# For  RF
# Accuracy -  0.9758220502901354
# Precision -  0.9829059829059829
# For  AdaBoost
# Accuracy -  0.960348162475822
# Precision -  0.9292035398230089
# For  BgC
# Accuracy -  0.9584139264990329
# Precision -  0.8682170542635659
# For  ETC
# Accuracy -  0.9748549323017408
# Precision -  0.9745762711864406
# For  GBDT
# Accuracy -  0.9468085106382979
# Precision -  0.9191919191919192
# For  xgb
# Accuracy -  0.9671179883945842
# Precision -  0.9262295081967213

# %%
performance_df=pd.DataFrame({"Algorithms":list(clfs.keys()),
                             'Accuracy_score':accuracy_scores,
                             "Precision_score":precision_scores}).sort_values(by='Precision_score',ascending=False)

# %%
performance_df
# Out:
#    Algorithms  Accuracy_score  Precision_score
# 1          KN        0.900387         1.000000
# 2          NB        0.959381         1.000000
# 5          RF        0.971954         1.000000
# 8         ETC        0.972921         0.982456
# 0         SVC        0.972921         0.974138
# 6    AdaBoost        0.961315         0.945455
# 10        xgb        0.972921         0.943548
# 4          LR        0.951644         0.940000
# 9        GBDT        0.952611         0.923810
# 7         BgC        0.958414         0.862595
# 3          DT        0.935203         0.838095

# %%
plt.figure(figsize=(12, 6))

# Accuracy plot
plt.bar(performance_df['Algorithms'], performance_df['Accuracy_score'], color='skyblue', label='Accuracy Score')

# Precision plot
plt.bar(performance_df['Algorithms'], performance_df['Precision_score'], color='salmon', label='Precision Score', alpha=0.7)

plt.title('Accuracy and Precision Scores for Different Algorithms')
plt.xlabel('Algorithms')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.legend()
plt.ylim(0.6, 1.0)

# plt.tight_layout()
plt.show()

# %%
performance_df1 = pd.melt(performance_df, id_vars = "Algorithms")

# %%
performance_df1
# Out:
#    Algorithms         variable     value
# 0          KN   Accuracy_score  0.900387
# 1          NB   Accuracy_score  0.959381
# 2          RF   Accuracy_score  0.971954
# 3         ETC   Accuracy_score  0.972921
# 4         SVC   Accuracy_score  0.972921
# 5    AdaBoost   Accuracy_score  0.961315
# 6         xgb   Accuracy_score  0.972921
# 7          LR   Accuracy_score  0.951644
# 8        GBDT   Accuracy_score  0.952611
# 9         BgC   Accuracy_score  0.958414
# 10         DT   Accuracy_score  0.935203
# 11         KN  Precision_score  1.000000
# 12         NB  Precision_score  1.000000
# 13         RF  Precision_score  1.000000
# 14        ETC  Precision_score  0.982456
# 15        SVC  Precision_score  0.974138
# 16   AdaBoost  Precision_score  0.945455
# 17        xgb  Precision_score  0.943548
# 18         LR  Precision_score  0.940000
# 19       GBDT  Precision_score  0.923810
# 20        BgC  Precision_score  0.862595
# 21         DT  Precision_score  0.838095

# %%
sns.catplot(x = 'Algorithms', y='value', 
               hue = 'variable',data=performance_df1, kind='bar',height=5)
plt.ylim(0.5,1.0)
plt.xticks(rotation='vertical')
plt.show()

# %%
# model improve
# 1. Change the max_features parameter of TfIdf

# %%
pd.DataFrame({'Algorithms':clfs.keys(),'Accuracy_score_3000':accuracy_scores,'Precision_score_3000':precision_scores}).sort_values('Precision_score_3000',ascending=False)
# Out:
#    Algorithms  Accuracy_score_3000  Precision_score_3000
# 1          KN             0.905222              1.000000
# 2          NB             0.970986              1.000000
# 5          RF             0.975822              0.982906
# 0         SVC             0.975822              0.974790
# 8         ETC             0.974855              0.974576
# 4          LR             0.958414              0.970297
# 6    AdaBoost             0.960348              0.929204
# 10        xgb             0.967118              0.926230
# 9        GBDT             0.946809              0.919192
# 7         BgC             0.958414              0.868217
# 3          DT             0.932302              0.833333

# %%
temp_df = pd.DataFrame({'Algorithms':clfs.keys(),'Accuracy_score_3000':accuracy_scores,'Precision_score_3000':precision_scores}).sort_values('Precision_score_3000',ascending=False)

# %%
new_df = performance_df.merge(temp_df,on='Algorithms')

# %%
new_df
# Out:
#    Algorithms  Accuracy_score  Precision_score  Accuracy_score_3000  \
# 0          KN        0.900387         1.000000             0.905222
# 1          NB        0.959381         1.000000             0.970986
# 2          RF        0.971954         1.000000             0.975822
# 3         ETC        0.972921         0.982456             0.974855
# 4         SVC        0.972921         0.974138             0.975822
# 5    AdaBoost        0.961315         0.945455             0.960348
# 6         xgb        0.972921         0.943548             0.967118
# 7          LR        0.951644         0.940000             0.958414
# 8        GBDT        0.952611         0.923810             0.946809
# 9         BgC        0.958414         0.862595             0.958414
# 10         DT        0.935203         0.838095             0.932302
#
#     Precision_score_3000
# 0               1.000000
# 1               1.000000
# 2               0.982906
# 3               0.974576
# ...

# %%
plt.figure(figsize=(23 ,8))

plt.subplot(1,2,1)
# Accuracy plot
plt.bar(performance_df['Algorithms'], performance_df['Accuracy_score'], color='skyblue', label='Accuracy Score')

# Precision plot
plt.bar(performance_df['Algorithms'], performance_df['Precision_score'], color='salmon', label='Precision Score', alpha=0.7)

plt.title('Accuracy and Precision Scores for Different Algorithms')
plt.xlabel('Algorithms')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.legend()
plt.ylim(0.6, 1.0)

plt.subplot(1,2,2)
# Accuracy plot
plt.bar(temp_df['Algorithms'], temp_df['Accuracy_score_3000'], color='skyblue', label='Accuracy Score')

# Precision plot
plt.bar(temp_df['Algorithms'], temp_df['Precision_score_3000'], color='salmon', label='Precision Score', alpha=0.7)

plt.title('Accuracy and Precision Scores After TFidf max Features')
plt.xlabel('Algorithms')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.legend()
plt.ylim(0.6, 1.0)

# plt.tight_layout()
plt.show()

# %% [markdown]
# ## Voting Classifier
#
# A voting classifier is an ensemble learning technique where multiple different machine learning models are combined to create a single, more robust model. A voting classifier can work in two ways:
#
# ## Hard Voting:
#
# Each model makes its prediction, and the final prediction is the one that the majority of the models have predicted.
#
# **Example:** If there are 3 models and 2 of them predict class A and 1 predicts class B, the final prediction will be class A.
#
# ## Soft Voting:
#
# Each model provides the probabilities of its predictions, and the final prediction is the class with the highest average probability.
#
# **Example:** If there are 3 models and they give probabilities of 0.6, 0.7, and 0.5 for class A, the final probability for class A will be (0.6 + 0.7 + 0.5) / 3 = 0.6.

# %%
# Voting Classifier
knc= KNeighborsClassifier()
svc = SVC(kernel='sigmoid', gamma=1.0, probability=True)
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
mnb = MultinomialNB()

# %%
from sklearn.ensemble import VotingClassifier

# %%
voting=VotingClassifier(estimators=[('svm', svc), ('nb', mnb), ('et', etc),('knn',knc),('rfc',rfc)],voting='soft')

# %%
voting
# Out:
# VotingClassifier(estimators=[('svm',
#                               SVC(gamma=1.0, kernel='sigmoid',
#                                   probability=True)),
#                              ('nb', MultinomialNB()),
#                              ('et',
#                               ExtraTreesClassifier(n_estimators=50,
#                                                    random_state=2)),
#                              ('knn', KNeighborsClassifier()),
#                              ('rfc',
#                               RandomForestClassifier(n_estimators=50,
#                                                      random_state=2))],
#                  voting='soft')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
voting.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('svm',
#                               SVC(gamma=1.0, kernel='sigmoid',
#                                   probability=True)),
#                              ('nb', MultinomialNB()),
#                              ('et',
#                               ExtraTreesClassifier(n_estimators=50,
#                                                    random_state=2)),
#                              ('knn', KNeighborsClassifier()),
#                              ('rfc',
#                               RandomForestClassifier(n_estimators=50,
#                                                      random_state=2))],
#                  voting='soft')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y_pred = voting.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.97678916827853
# Precision 1.0

# %%
# Applying stacking
estimators=[('svm', svc), ('nb', mnb), ('et', etc),('knn',knc),('rfc',rfc)]
final_estimator=RandomForestClassifier()

# %%
from sklearn.ensemble import StackingClassifier

# %%
clf = StackingClassifier(estimators=estimators, final_estimator=final_estimator)

# %%
clf
# Out:
# StackingClassifier(estimators=[('svm',
#                                 SVC(gamma=1.0, kernel='sigmoid',
#                                     probability=True)),
#                                ('nb', MultinomialNB()),
#                                ('et',
#                                 ExtraTreesClassifier(n_estimators=50,
#                                                      random_state=2)),
#                                ('knn', KNeighborsClassifier()),
#                                ('rfc',
#                                 RandomForestClassifier(n_estimators=50,
#                                                        random_state=2))],
#                    final_estimator=RandomForestClassifier())

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
clf.fit(X_train,y_train)
# Out:
# StackingClassifier(estimators=[('svm',
#                                 SVC(gamma=1.0, kernel='sigmoid',
#                                     probability=True)),
#                                ('nb', MultinomialNB()),
#                                ('et',
#                                 ExtraTreesClassifier(n_estimators=50,
#                                                      random_state=2)),
#                                ('knn', KNeighborsClassifier()),
#                                ('rfc',
#                                 RandomForestClassifier(n_estimators=50,
#                                                        random_state=2))],
#                    final_estimator=RandomForestClassifier())

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y_pred = clf.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.9806576402321083
# Precision 0.9538461538461539

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
